# %% [markdown]
# <a href="https://colab.research.google.com/github/davidpower007/calculus-and-algebra-problems-with-python/blob/main/calculus_algebra_ult.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Ejercicio 1
#Supongamos que, en mi oficina, me toma 10 segundos (tiempo) recorrer 25 metros (distancia) hasta la máquina de café

tiempo = 10
distancia = 25
velocidad = (25/10)

# %%
velocidad
# Out:
# 2.5

# %%
def f(x): return 2.5*x
x = np.linspace(0,10)

# %%
plt.plot(x, f(x))

# %%
f1 = pd.DataFrame({'x': x, 'f(x)': f(x)})
f1.head()
# Out:
#           x      f(x)
# 0  0.000000  0.000000
# 1  0.204082  0.010412
# 2  0.408163  0.041649
# 3  0.612245  0.093711
# 4  0.816327  0.166597

# %%
# Ejercicio 2
def f(x): return 1/2*0.5*(x**2)
x = np.linspace(0,10)
plt.plot(x, f(x))

# %%
f2 = pd.DataFrame({'x': x, 'f(x)': f(x)})
f2.head()
# Out:
#           x      f(x)
# 0  0.000000  0.000000
# 1  0.204082  0.010412
# 2  0.408163  0.041649
# 3  0.612245  0.093711
# 4  0.816327  0.166597

# %%
#Ejercicio 3
def f(x):
  return (0.1*(x**2)) - (9*x) + 4500

# %%
costos = []
Xs = range(0, 100)
for x in Xs:
  costos.append(f(x))

# %%
plt.plot(Xs, costos)

# %%
#Álgebra lineal
#Ejercicio 1: Suma de dos matrices
import numpy as np
A = np.array([[1, 2], [3, 4]])
B = np.array([[4, 5], [6, 7]])

# %%
print(A)
print(B)
# Out:
# [[1 2]
#  [3 4]]
# [[4 5]
#  [6 7]]

# %%
print(np.add(A, B))
# Out:
# [[ 5  7]
#  [ 9 11]]

# %%
#Ejercicio 2: Suma de dos listas
list1 = [2, 5, 4, 7, 3]
list2 = [1, 4, 6, 9, 10]
print ("Original list 1 : " + str(list1))
print ("Original list 2 : " + str(list2))
# Out:
# Original list 1 : [2, 5, 4, 7, 3]
# Original list 2 : [1, 4, 6, 9, 10]

# %%
res_list = []
for i in range(0, len(list1)):
    res_list.append(list1[i] + list2[i])

# %%
print ("Resulting list is : " + str(res_list))
# Out:
# Resulting list is : [3, 9, 10, 16, 13]

# %%
list1 = [1, 3, 4, 6, 8]
list2 = [4, 5, 6, 2, 10]
print ("Original list 1 : " + str(list1))
print ("Original list 2 : " + str(list2))
res_list = [list1[i] + list2[i] for i in range(len(list1))]
# Out:
# Original list 1 : [1, 3, 4, 6, 8]
# Original list 2 : [4, 5, 6, 2, 10]

# %%
print ("Resulting list is : " + str(res_list))
# Out:
# Resulting list is : [5, 8, 10, 8, 18]

# %%
from operator import add

list1 = [1, 3, 4, 6, 8]
list2 = [4, 5, 6, 2, 10]

print ("Original list 1 : " + str(list1))
print ("Original list 2 : " + str(list2))
res_list = list(map(add, list1, list2))
print ("Resulting list is : " + str(res_list))
# Out:
# Original list 1 : [1, 3, 4, 6, 8]
# Original list 2 : [4, 5, 6, 2, 10]
# Resulting list is : [5, 8, 10, 8, 18]

# %%
from operator import add

list1 = [1, 3, 4, 6, 8]
list2 = [4, 5, 6, 2, 10]

print ("Original list 1 : " + str(list1))
print ("Original list 2 : " + str(list2))

res_list = [sum(i) for i in zip(list1, list2)]
print ("Resulting list is : " + str(res_list))
# Out:
# Original list 1 : [1, 3, 4, 6, 8]
# Original list 2 : [4, 5, 6, 2, 10]
# Resulting list is : [5, 8, 10, 8, 18]

# %%
#Ejercicio 3: Multiplicación punto a punto
matrix1 = [[1,7,3],
 [4,5,2],
 [3,6,1]]
matrix2 = [[5,4,1],
 [1,2,3],
 [4,5,2]]

res = [[0 for x in range(3)] for y in range(3)]


for i in range(len(matrix1)):
    for j in range(len(matrix2[0])):
        for k in range(len(matrix2)):

            res[i][j] += matrix1[i][k] * matrix2[k][j]

print(res)
# Out:
# [[24, 33, 28], [33, 36, 23], [25, 29, 23]]

# %%
mat1 = ([1,7,3],[ 4,5,2],[ 3,6,1])
mat2 = ([5,4,1],[ 1,2,3],[ 4,5,2])
res = np.dot(mat1,mat2)
print(res)
# Out:
# [[24 33 28]
#  [33 36 23]
#  [25 29 23]]
